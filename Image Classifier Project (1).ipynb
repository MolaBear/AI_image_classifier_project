# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'


import numpy as np
import time

import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

from collections import OrderedDict
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

orig_img_size = 256
new_img_size = 224
means = [0.485, 0.456, 0.406]
std_dev = [0.229, 0.224, 0.225]

train_transform_set = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(new_img_size),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize(means, std_dev)])

test_transform_set = transforms.Compose([transforms.Resize(orig_img_size),
                                      transforms.CenterCrop(new_img_size),
                                      transforms.ToTensor(),
                                      transforms.Normalize(means, std_dev)])

valid_transform_set = transforms.Compose([transforms.Resize(orig_img_size),
                                            transforms.CenterCrop(new_img_size),
                                            transforms.ToTensor(),
                                            transforms.Normalize(means, std_dev)])

# TODO: Load the datasets with ImageFolder
train_dataset = datasets.ImageFolder(train_dir, transform = train_transform_set)
valid_dataset = datasets.ImageFolder(valid_dir, transform = valid_transform_set)
test_dataset  = datasets.ImageFolder(test_dir , transform = test_transform_set)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loaders = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
valid_loaders = torch.utils.data.DataLoader(valid_dataset, batch_size=64, shuffle=True)
test_loaders  = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    
print (len(cat_to_name))
# Out:
# 102

# %%
#Test data loaders
images, labels = next(iter(test_loaders))
print(len(images[1,1]))
plt.imshow(images[0,0])
# Out:
# 224

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
dropout=0.5

def model_setup(dropout=0.5):
    
    # Number of output units from the vgg16
    vgg16 = 25088
    
    model = models.vgg16(pretrained=True)  

    # Freeze parameters so we don't backprop through them
    for param in model.parameters():
        param.requires_grad = False

    from collections import OrderedDict
    classifier = nn.Sequential(OrderedDict([
                                  ('dropout',nn.Dropout(dropout)),
                                  ('inputs', nn.Linear(vgg16, 100)),
                                  ('relu1', nn.ReLU()),
                                  ('hidden_layer_1', nn.Linear(100, 90)),
                                  ('relu2',nn.ReLU()),
                                  ('hidden_layer_2',nn.Linear(90, 80)),
                                  ('relu3',nn.ReLU()),
                                  ('hidden_layer_3',nn.Linear(80, 102)),
                                  ('output', nn.LogSoftmax(dim=1))
                              ]))

    model.classifier = classifier

    return model

model = model_setup(dropout)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 108356980.63it/s]

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
# Get GPU/CPU automatically
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate=0.001
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=learning_rate )

model.to(device)


train_losses, valid_losses = [], []
def train(epochs = 10, print_every = 6,):
    steps = 0
    for e in range(epochs):
        model.train()
        running_loss = 0

        for ii, (inputs, labels) in enumerate(train_loaders):
            steps += 1

            # Move input and label tensors to the GPU (if available)
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            # Forward and backward passes
            outputs = model.forward(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if steps % print_every == 0:
                # Deactivate dropout
                model.eval()
                valid_loss = 0
                accuracy = 0

                for ii, (valid_inputs, valid_labels) in enumerate(valid_loaders):
                    optimizer.zero_grad()

                    # We will keep using the training hardware for validation (cuda or cpu)
                    valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device) 
                    model.to(device)

                    with torch.no_grad():    
                        outputs = model.forward(valid_inputs)
                        valid_loss = criterion(outputs, valid_labels)
                        ps = torch.exp(outputs).data 
                        equality = (valid_labels.data == ps.max(1)[1])
                        accuracy += equality.type_as(torch.FloatTensor()).mean()

                valid_loss = valid_loss / len(valid_loaders)
                train_loss = running_loss / len(train_loaders)

                train_losses.append(train_loss)
                valid_losses.append(valid_loss)

                accuracy = (accuracy /len(valid_loaders)) * 100

                print("Epoch: {}/{}... ".format(e+1, epochs),
                      "Loss: {:.4f}".format(running_loss/print_every),
                      "Validation Loss {:.4f}".format(valid_loss),
                      "Accuracy: {:.4f}%".format(accuracy))

                running_loss = 0
                # Done evaluating now return model back to training.
                model.train()
                
print("--------------Training has started------------- ")       
train()
print("-------------- Finished training -----------------------")
# Out:
# --------------Training has started-------------
# Epoch: 1/10...  Loss: 4.6147 Validation Loss 0.3531 Accuracy: 1.7500%
# Epoch: 1/10...  Loss: 4.5537 Validation Loss 0.3430 Accuracy: 7.3125%
# Epoch: 1/10...  Loss: 4.4048 Validation Loss 0.3349 Accuracy: 9.5625%
# Epoch: 1/10...  Loss: 4.2661 Validation Loss 0.3380 Accuracy: 8.2740%
# Epoch: 1/10...  Loss: 4.2068 Validation Loss 0.3150 Accuracy: 11.3125%
# Epoch: 1/10...  Loss: 4.0856 Validation Loss 0.2769 Accuracy: 14.7596%
# Epoch: 1/10...  Loss: 3.8933 Validation Loss 0.2434 Accuracy: 18.5000%
# Epoch: 1/10...  Loss: 3.8794 Validation Loss 0.2331 Accuracy: 23.3029%
# Epoch: 1/10...  Loss: 3.5207 Validation Loss 0.2527 Accuracy: 27.7067%
# Epoch: 1/10...  Loss: 3.3154 Validation Loss 0.2347 Accuracy: 30.3510%
# Epoch: 1/10...  Loss: 3.1863 Validation Loss 0.2156 Accuracy: 38.0721%
# Epoch: 1/10...  Loss: 3.1495 Validation Loss 0.2073 Accuracy: 36.0962%
# Epoch: 1/10...  Loss: 2.9551 Validation Loss 0.1849 Accuracy: 42.7212%
# Epoch: 1/10...  Loss: 2.9496 Validation Loss 0.1796 Accuracy: 41.5048%
# Epoch: 1/10...  Loss: 2.5257 Validation Loss 0.1500 Accuracy: 51.0481%
# Epoch: 1/10...  Loss: 2.4760 Validation Loss 0.1471 Accuracy: 49.0721%
# Epoch: 1/10...  Loss: 2.4567 Validation Loss 0.1289 Accuracy: 50.8221%
# Epoch: 2/10...  Loss: 1.7492 Validation Loss 0.1471 Accuracy: 54.4327%
# Epoch: 2/10...  Loss: 2.0921 Validation Loss 0.0986 Accuracy: 53.8269%
# Epoch: 2/10...  Loss: 2.1080 Validation Loss 0.0912 Accuracy: 59.7452%
# Epoch: 2/10...  Loss: 2.0213 Validation Loss 0.1038 Accuracy: 59.6971%
# Epoch: 2/10...  Loss: 2.0717 Validation Loss 0.1095 Accuracy: 57.4663%
# Epoch: 2/10...  Loss: 2.0316 Validation Loss 0.1098 Accuracy: 57.1394%
# Epoch: 2/10...  Loss: 1.7717 Validation Loss 0.0958 Accuracy: 62.8221%
# Epoch: 2/10...  Loss: 1.8505 Validation Loss 0.1027 Accuracy: 64.6394%
# Epoch: 2/10...  Loss: 1.8178 Validation Loss 0.1051 Accuracy: 63.8702%
# Epoch: 2/10...  Loss: 1.8119 Validation Loss 0.1121 Accuracy: 66.2212%
# Epoch: 2/10...  Loss: 1.8214 Validation Loss 0.1061 Accuracy: 63.0625%
# Epoch: 2/10...  Loss: 1.7726 Validation Loss 0.0960 Accuracy: 66.1202%
# Epoch: 2/10...  Loss: 1.6879 Validation Loss 0.1170 Accuracy: 64.1779%
# Epoch: 2/10...  Loss: 1.6207 Validation Loss 0.0719 Accuracy: 64.4327%
# Epoch: 2/10...  Loss: 1.5258 Validation Loss 0.0641 Accuracy: 70.2163%
# Epoch: 2/10...  Loss: 1.7080 Validation Loss 0.0645 Accuracy: 69.7356%
# Epoch: 2/10...  Loss: 1.4449 Validation Loss 0.0611 Accuracy: 71.1298%
# Epoch: 3/10...  Loss: 1.0391 Validation Loss 0.0929 Accuracy: 68.8654%
# Epoch: 3/10...  Loss: 1.4306 Validation Loss 0.0665 Accuracy: 70.6490%
# Epoch: 3/10...  Loss: 1.4011 Validation Loss 0.0770 Accuracy: 71.7837%
# Epoch: 3/10...  Loss: 1.4713 Validation Loss 0.0544 Accuracy: 73.9952%
# Epoch: 3/10...  Loss: 1.4785 Validation Loss 0.0704 Accuracy: 71.5769%
# Epoch: 3/10...  Loss: 1.3899 Validation Loss 0.0449 Accuracy: 73.7019%
# Epoch: 3/10...  Loss: 1.3565 Validation Loss 0.0792 Accuracy: 69.4471%
# Epoch: 3/10...  Loss: 1.4018 Validation Loss 0.0623 Accuracy: 70.8221%
# Epoch: 3/10...  Loss: 1.3892 Validation Loss 0.0651 Accuracy: 75.8173%
# Epoch: 3/10...  Loss: 1.4937 Validation Loss 0.0739 Accuracy: 74.1346%
# Epoch: 3/10...  Loss: 1.2783 Validation Loss 0.0796 Accuracy: 73.7212%
# Epoch: 3/10...  Loss: 1.2782 Validation Loss 0.0651 Accuracy: 72.4327%
# Epoch: 3/10...  Loss: 1.4346 Validation Loss 0.0421 Accuracy: 75.6923%
# Epoch: 3/10...  Loss: 1.3078 Validation Loss 0.0758 Accuracy: 76.9183%
# Epoch: 3/10...  Loss: 1.2944 Validation Loss 0.0469 Accuracy: 76.1731%
# Epoch: 3/10...  Loss: 1.2173 Validation Loss 0.0568 Accuracy: 77.0000%
# Epoch: 3/10...  Loss: 1.3068 Validation Loss 0.0476 Accuracy: 78.3702%
# Epoch: 4/10...  Loss: 0.6224 Validation Loss 0.0392 Accuracy: 76.9279%
# Epoch: 4/10...  Loss: 1.2965 Validation Loss 0.0723 Accuracy: 77.9279%
# Epoch: 4/10...  Loss: 1.2599 Validation Loss 0.0512 Accuracy: 78.9712%
# Epoch: 4/10...  Loss: 1.1525 Validation Loss 0.0495 Accuracy: 76.9135%
# Epoch: 4/10...  Loss: 1.4602 Validation Loss 0.0739 Accuracy: 79.0625%
# Epoch: 4/10...  Loss: 1.1463 Validation Loss 0.0613 Accuracy: 74.6827%
# Epoch: 4/10...  Loss: 1.1145 Validation Loss 0.0634 Accuracy: 78.2548%
# Epoch: 4/10...  Loss: 1.2318 Validation Loss 0.1004 Accuracy: 80.7115%
# Epoch: 4/10...  Loss: 1.2642 Validation Loss 0.0471 Accuracy: 79.5240%
# Epoch: 4/10...  Loss: 1.0988 Validation Loss 0.0349 Accuracy: 78.4567%
# Epoch: 4/10...  Loss: 1.1966 Validation Loss 0.0558 Accuracy: 78.3221%
# Epoch: 4/10...  Loss: 1.1510 Validation Loss 0.0785 Accuracy: 79.1827%
# Epoch: 4/10...  Loss: 1.1529 Validation Loss 0.0565 Accuracy: 79.9183%
# Epoch: 4/10...  Loss: 1.1569 Validation Loss 0.0705 Accuracy: 81.3077%
# Epoch: 4/10...  Loss: 1.1826 Validation Loss 0.0372 Accuracy: 80.6538%
# Epoch: 4/10...  Loss: 1.1269 Validation Loss 0.0656 Accuracy: 78.6635%
# Epoch: 4/10...  Loss: 1.1284 Validation Loss 0.0584 Accuracy: 82.2019%
# Epoch: 5/10...  Loss: 0.3129 Validation Loss 0.0680 Accuracy: 84.2308%
# Epoch: 5/10...  Loss: 1.0483 Validation Loss 0.0423 Accuracy: 80.8269%
# Epoch: 5/10...  Loss: 1.0539 Validation Loss 0.0647 Accuracy: 79.6298%
# Epoch: 5/10...  Loss: 1.0677 Validation Loss 0.0514 Accuracy: 83.5913%
# Epoch: 5/10...  Loss: 1.0875 Validation Loss 0.0908 Accuracy: 82.5625%
# Epoch: 5/10...  Loss: 0.9767 Validation Loss 0.0375 Accuracy: 82.4231%
# Epoch: 5/10...  Loss: 1.1386 Validation Loss 0.0310 Accuracy: 82.8510%
# Epoch: 5/10...  Loss: 0.8950 Validation Loss 0.0429 Accuracy: 82.7837%
# Epoch: 5/10...  Loss: 1.0549 Validation Loss 0.0497 Accuracy: 79.0433%
# Epoch: 5/10...  Loss: 1.1630 Validation Loss 0.0461 Accuracy: 82.7837%
# Epoch: 5/10...  Loss: 0.9094 Validation Loss 0.0370 Accuracy: 81.8558%
# Epoch: 5/10...  Loss: 1.0095 Validation Loss 0.0645 Accuracy: 81.0000%
# Epoch: 5/10...  Loss: 1.2084 Validation Loss 0.0420 Accuracy: 81.2019%
# Epoch: 5/10...  Loss: 1.0615 Validation Loss 0.0404 Accuracy: 82.2163%
# Epoch: 5/10...  Loss: 1.0622 Validation Loss 0.0287 Accuracy: 83.5192%
# Epoch: 5/10...  Loss: 1.1431 Validation Loss 0.0578 Accuracy: 82.2019%
# Epoch: 5/10...  Loss: 1.0824 Validation Loss 0.0444 Accuracy: 80.7404%
# Epoch: 6/10...  Loss: 0.1959 Validation Loss 0.0533 Accuracy: 81.9952%
# Epoch: 6/10...  Loss: 0.9515 Validation Loss 0.0487 Accuracy: 81.6683%
# Epoch: 6/10...  Loss: 1.1760 Validation Loss 0.0447 Accuracy: 82.7692%
# Epoch: 6/10...  Loss: 1.1669 Validation Loss 0.0604 Accuracy: 84.1923%
# Epoch: 6/10...  Loss: 1.0177 Validation Loss 0.0312 Accuracy: 82.1298%
# Epoch: 6/10...  Loss: 1.0913 Validation Loss 0.0607 Accuracy: 80.8606%
# Epoch: 6/10...  Loss: 0.9171 Validation Loss 0.0435 Accuracy: 81.8221%
# Epoch: 6/10...  Loss: 0.9644 Validation Loss 0.0583 Accuracy: 80.7067%
# Epoch: 6/10...  Loss: 1.1030 Validation Loss 0.0487 Accuracy: 82.4231%
# Epoch: 6/10...  Loss: 1.1130 Validation Loss 0.0469 Accuracy: 83.4038%
# Epoch: 6/10...  Loss: 0.8711 Validation Loss 0.0385 Accuracy: 84.4327%
# Epoch: 6/10...  Loss: 1.1905 Validation Loss 0.0511 Accuracy: 86.0817%
# Epoch: 6/10...  Loss: 0.9353 Validation Loss 0.0286 Accuracy: 85.3750%
# Epoch: 6/10...  Loss: 1.0231 Validation Loss 0.0255 Accuracy: 84.5673%
# Epoch: 6/10...  Loss: 0.9831 Validation Loss 0.0450 Accuracy: 82.6635%
# Epoch: 6/10...  Loss: 1.0583 Validation Loss 0.0411 Accuracy: 83.2644%
# Epoch: 6/10...  Loss: 1.0708 Validation Loss 0.0338 Accuracy: 83.9519%
# Epoch: 6/10...  Loss: 0.9959 Validation Loss 0.0606 Accuracy: 84.0385%
# Epoch: 7/10...  Loss: 0.9929 Validation Loss 0.0520 Accuracy: 84.0721%
# Epoch: 7/10...  Loss: 1.1085 Validation Loss 0.0388 Accuracy: 85.0144%
# Epoch: 7/10...  Loss: 0.9985 Validation Loss 0.0512 Accuracy: 85.0865%
# Epoch: 7/10...  Loss: 0.9637 Validation Loss 0.0418 Accuracy: 86.4904%
# Epoch: 7/10...  Loss: 1.0066 Validation Loss 0.0436 Accuracy: 85.5817%
# Epoch: 7/10...  Loss: 0.8724 Validation Loss 0.0362 Accuracy: 84.1731%
# Epoch: 7/10...  Loss: 0.9722 Validation Loss 0.0392 Accuracy: 85.8558%
# Epoch: 7/10...  Loss: 0.8876 Validation Loss 0.0293 Accuracy: 84.7740%
# Epoch: 7/10...  Loss: 0.9479 Validation Loss 0.0374 Accuracy: 85.7692%
# Epoch: 7/10...  Loss: 0.8414 Validation Loss 0.0531 Accuracy: 86.4615%
# Epoch: 7/10...  Loss: 0.8070 Validation Loss 0.0307 Accuracy: 85.3413%
# Epoch: 7/10...  Loss: 0.9151 Validation Loss 0.0552 Accuracy: 83.9712%
# Epoch: 7/10...  Loss: 0.9229 Validation Loss 0.0562 Accuracy: 82.5962%
# Epoch: 7/10...  Loss: 1.1032 Validation Loss 0.0261 Accuracy: 84.9615%
# Epoch: 7/10...  Loss: 0.9642 Validation Loss 0.0427 Accuracy: 84.6202%
# Epoch: 7/10...  Loss: 1.0243 Validation Loss 0.0442 Accuracy: 85.5481%
# Epoch: 7/10...  Loss: 0.8801 Validation Loss 0.0382 Accuracy: 85.8413%
# Epoch: 8/10...  Loss: 0.6651 Validation Loss 0.0286 Accuracy: 87.2981%
# Epoch: 8/10...  Loss: 0.9216 Validation Loss 0.0612 Accuracy: 86.8029%
# Epoch: 8/10...  Loss: 0.9148 Validation Loss 0.0342 Accuracy: 85.1875%
# Epoch: 8/10...  Loss: 0.8932 Validation Loss 0.0336 Accuracy: 83.6587%
# Epoch: 8/10...  Loss: 0.9309 Validation Loss 0.0406 Accuracy: 85.4615%
# Epoch: 8/10...  Loss: 0.8822 Validation Loss 0.0446 Accuracy: 85.9952%
# Epoch: 8/10...  Loss: 0.9027 Validation Loss 0.0194 Accuracy: 83.6394%
# Epoch: 8/10...  Loss: 0.9158 Validation Loss 0.0285 Accuracy: 86.4231%
# Epoch: 8/10...  Loss: 0.8497 Validation Loss 0.0519 Accuracy: 86.5096%
# Epoch: 8/10...  Loss: 1.0540 Validation Loss 0.0540 Accuracy: 88.2452%
# Epoch: 8/10...  Loss: 0.8154 Validation Loss 0.0170 Accuracy: 86.6779%
# Epoch: 8/10...  Loss: 0.9493 Validation Loss 0.0402 Accuracy: 84.8077%
# Epoch: 8/10...  Loss: 0.8787 Validation Loss 0.0307 Accuracy: 84.8077%
# Epoch: 8/10...  Loss: 1.0482 Validation Loss 0.0220 Accuracy: 86.6779%
# Epoch: 8/10...  Loss: 0.8668 Validation Loss 0.0236 Accuracy: 86.4904%
# Epoch: 8/10...  Loss: 1.0205 Validation Loss 0.0372 Accuracy: 85.1346%
# Epoch: 8/10...  Loss: 1.0228 Validation Loss 0.0457 Accuracy: 85.7548%
# Epoch: 9/10...  Loss: 0.5162 Validation Loss 0.0497 Accuracy: 87.0240%
# Epoch: 9/10...  Loss: 0.8193 Validation Loss 0.0265 Accuracy: 87.6587%
# Epoch: 9/10...  Loss: 0.8918 Validation Loss 0.0448 Accuracy: 84.0385%
# Epoch: 9/10...  Loss: 0.9334 Validation Loss 0.0257 Accuracy: 86.3365%
# Epoch: 9/10...  Loss: 1.0693 Validation Loss 0.0234 Accuracy: 87.2981%
# Epoch: 9/10...  Loss: 0.8996 Validation Loss 0.0326 Accuracy: 86.5096%
# Epoch: 9/10...  Loss: 0.7790 Validation Loss 0.0195 Accuracy: 86.6106%
# Epoch: 9/10...  Loss: 0.8286 Validation Loss 0.0243 Accuracy: 85.0481%
# Epoch: 9/10...  Loss: 0.8150 Validation Loss 0.0256 Accuracy: 87.2452%
# Epoch: 9/10...  Loss: 0.7768 Validation Loss 0.0328 Accuracy: 86.5961%
# Epoch: 9/10...  Loss: 0.7739 Validation Loss 0.0340 Accuracy: 89.1202%
# Epoch: 9/10...  Loss: 0.8157 Validation Loss 0.0283 Accuracy: 88.4471%
# Epoch: 9/10...  Loss: 0.7760 Validation Loss 0.0266 Accuracy: 85.5288%
# Epoch: 9/10...  Loss: 0.8826 Validation Loss 0.0335 Accuracy: 84.2788%
# Epoch: 9/10...  Loss: 0.8625 Validation Loss 0.0285 Accuracy: 87.4519%
# Epoch: 9/10...  Loss: 0.7753 Validation Loss 0.0185 Accuracy: 85.5288%
# Epoch: 9/10...  Loss: 0.9463 Validation Loss 0.0291 Accuracy: 88.1202%
# Epoch: 10/10...  Loss: 0.4559 Validation Loss 0.0471 Accuracy: 87.9519%
# Epoch: 10/10...  Loss: 0.9196 Validation Loss 0.0253 Accuracy: 87.8990%
# Epoch: 10/10...  Loss: 0.8396 Validation Loss 0.0209 Accuracy: 86.6106%
# Epoch: 10/10...  Loss: 0.8802 Validation Loss 0.0279 Accuracy: 85.2356%
# Epoch: 10/10...  Loss: 0.8147 Validation Loss 0.0268 Accuracy: 86.7644%
# Epoch: 10/10...  Loss: 0.9034 Validation Loss 0.0318 Accuracy: 88.3606%
# Epoch: 10/10...  Loss: 0.8758 Validation Loss 0.0278 Accuracy: 87.8125%
# Epoch: 10/10...  Loss: 0.8232 Validation Loss 0.0300 Accuracy: 86.6635%
# Epoch: 10/10...  Loss: 0.8248 Validation Loss 0.0273 Accuracy: 86.3365%
# Epoch: 10/10...  Loss: 0.8860 Validation Loss 0.0451 Accuracy: 86.1154%
# Epoch: 10/10...  Loss: 0.7456 Validation Loss 0.0144 Accuracy: 86.0433%
# Epoch: 10/10...  Loss: 0.8657 Validation Loss 0.0672 Accuracy: 86.1154%
# Epoch: 10/10...  Loss: 0.8844 Validation Loss 0.0641 Accuracy: 85.7740%
# Epoch: 10/10...  Loss: 0.9545 Validation Loss 0.0307 Accuracy: 89.0144%
# Epoch: 10/10...  Loss: 0.8440 Validation Loss 0.0315 Accuracy: 87.8654%
# Epoch: 10/10...  Loss: 0.9542 Validation Loss 0.0405 Accuracy: 85.8750%
# Epoch: 10/10...  Loss: 0.8375 Validation Loss 0.0180 Accuracy: 86.3510%
# -------------- Finished training -----------------------

# %%
# Check accuracy on test dataset

accuracy = 0

for ii, (test_inputs, test_labels) in enumerate(test_loaders):
    # Move input and label tensors to the GPU (if available)
    test_inputs, test_labels = test_inputs.to(device), test_labels.to(device)

    # Get the class probabilities
    ps = torch.exp(model(test_inputs))
    
    # Make sure the shape is appropriate, we should get 102 class probabilities for 64 examples
    top_p, top_class = ps.topk(1, dim=1)
    
    # Look at the most likely classes for the first 10 examples
    equals = top_class == test_labels.view(*top_class.shape)
    
    accuracy += torch.mean(equals.type(torch.FloatTensor))
    
accuracy = accuracy /len(test_loaders)
print(f'Accuracy of the network on the test images: {accuracy.item()*100}%')
# Out:
# Accuracy of the network on the test images: 80.82343339920044%

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_dataset.class_to_idx

torch.save({'dropout': dropout,
            'learning_rate': learning_rate,
            'state_dict': model.state_dict(),
            'class_to_idx': model.class_to_idx},
            'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_model(path):
    checkpoint = torch.load('checkpoint.pth')
    dropout = checkpoint['dropout']
    model = model_setup(dropout)
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    
    return model

model = load_model('checkpoint.pth')

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):

    adjustments = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    return adjustments(Image.open(image))

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    
    image = std * image + mean
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/1/image_06743.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.to('cuda:0')
    img_torch = process_image(image_path)
    img_torch = img_torch.unsqueeze_(0).float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda())
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(topk)

img = ("flowers/test/10/image_07104.jpg")
predict(img, model)
# Out:
# (tensor([[ 0.9917,  0.0082,  0.0001,  0.0001,  0.0000]], device='cuda:0'),
#  tensor([[  1,   8,  24,  31,  11]], device='cuda:0'))

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# %%
def check_sanity(path):    
    probabilities = predict(path, model)
    
    # Plotting a flower image
    plt.rcParams["figure.figsize"] = (8,8)
    plt.subplot(211)
    image = process_image(path)
    flower_axs = imshow(image, ax = plt)
    flower_axs.axis('off')
    index = 1
    flower_axs.title(cat_to_name[str(index)])
    flower_axs.show()
    
    # Separating labels and probabilities
    top_probabilities = np.array(probabilities[0][0].cpu().numpy())
    top_label_probabilities = [cat_to_name[str(index + 1)] for index in np.array(probabilities[1][0])]
    
    # Plotting graph with all labels
    fig, graph_ax = plt.subplots(figsize=(5,3))
    y_pos = np.arange(float(len(top_probabilities)))
    graph_ax.barh(y_pos, top_probabilities, align='center')
    graph_ax.set_yticks(y_pos)
    graph_ax.set_yticklabels(top_label_probabilities)
    graph_ax.invert_yaxis()  # labels read top-to-bottom
    graph_ax.set_xlabel('Accuracy')  

    plt.show()

check_sanity(path='flowers/test/1/image_06743.jpg')

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
